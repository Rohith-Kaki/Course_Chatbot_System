# %%
from PyPDF2 import PdfReader
from nltk.tokenize import sent_tokenize

def extract_text_from_pdf(pdf_path):
    reader = PdfReader(pdf_path)
    text = ""
    for page in reader.pages:
        text += page.extract_text() + "\n"  # Extract text from each page
    return text

def split_text_into_chunks(text, max_tokens=100):
    sentences = sent_tokenize(text)  # Split into sentences
    chunks = []
    current_chunk = ""
    print(len(text))
    print(len(sentences[1]))
    print(sentences[1])
    for sentence in sentences:
        if len(current_chunk) + len(sentence) <= max_tokens:
            current_chunk += " " + sentence
        else:
            chunks.append(current_chunk.strip())
            current_chunk = sentence  # Start new chunk

    if current_chunk:
        chunks.append(current_chunk.strip())

    return chunks



text = extract_text_from_pdf("R:/CourseChabot/Backend/new/Books/school_tech_books/Learning_Python_part_1.pdf")
final_text = split_text_into_chunks(text)
print(final_text)
print(len(final_text))
# Out:
# 764121
# 149
# If you don’t, you probably won’t be sold on Python until you’ve
# learned the language by reading the rest of this book and have done a project or two.
# ...

# %%
print((final_text[24]))
# Out:
# Python’s third-party domain offers tools
# for website construction, numeric programming, serial port access, game devel-
# opment, and much more.

# %%
from sentence_transformers import SentenceTransformer
sentences = ["This is an example sentence", "Each sentence is converted"]

model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
embeddings = model.encode([final_text[24]])
print(embeddings)
# Out:
# [[-8.35231692e-02 -9.25538018e-02 -7.83222392e-02 -9.29508135e-02
#   -4.38805893e-02 -1.50430530e-01 -7.14431480e-02  9.47853923e-03
#   -1.87990554e-02  3.23322276e-03 -3.33684757e-02  2.96866763e-02
#    2.77634636e-02 -1.27330674e-02  1.62464082e-01 -2.17107758e-02
#   -1.72798838e-02  4.19238172e-02  9.19021890e-02 -1.05459288e-01
#    3.11595052e-02  6.93776980e-02 -1.00085726e-02 -5.00138663e-02
#   -1.04376115e-02 -4.44213860e-02  2.85735913e-02  5.34763709e-02
#    3.27291824e-02 -4.38938029e-02 -5.06401882e-02  5.25865033e-02
#   -1.03268456e-02  1.56941768e-02  4.40987945e-02  3.97450812e-02
#   -3.00547108e-02 -3.29901539e-02 -1.02361180e-01 -2.23907307e-02
#   -3.55874561e-03 -2.17562020e-02  5.25258062e-03  1.36751486e-02
#   -8.82254466e-02  3.62232402e-02 -8.26899633e-02  1.10253496e-02
#    3.54414806e-02 -2.81400345e-02  1.00060776e-02 -2.22721454e-02
#    2.90946453e-04 -5.76533489e-02 -5.79918735e-02 -2.68930662e-02
# ...
